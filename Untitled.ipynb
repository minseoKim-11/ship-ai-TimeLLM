# %%
import requests, json
url = "http://localhost:8000/tools/dislocation.analyze"
payload = {"companyName": "HD현대중공업", "analysisDate": "2024-12-31"}
r = requests.post(url, json=payload)
print(r.status_code)
print(json.dumps(r.json(), ensure_ascii=False, indent=2))
# Out:
# 200
# {
#   "companyName": "HD현대중공업",
#   "analysisDate": "2024-12-31",
#   "discrepancy": {
#     "score": 70.0,
#     "trend": "POSITIVE",
#     "summary": "임시 요약: 더미 밴드 기준 긍정적 괴리."
#   },
#   "timellm_band": {
#     "pred_horizon_days": 20,
#     "expected_price": 185995.1562,
#     "lower": 179647.3689,
#     "upper": 192342.9436,
#     "confidence": 0.68
#   },
#   "causalFactors": []
# }
