# %%
import sys, os
sys.path.append("/workspace/ship-ai")
from engine.tool1_stock_info import get_stock_info_engine

resp = get_stock_info_engine("010620", "2022-01-05", "2022-01-10")
resp
# Out:
# {'ticker': '010620',
#  'date_range': {'start': '2022-01-05', 'end': '2022-01-10'},
#  'time_series': {'close': [['2022-01-05', 79800.0],
#    ['2022-01-06', 81800.0],
#    ['2022-01-07', 82400.0],
#    ['2022-01-10', 81700.0]],
#   'ret_1d': [['2022-01-05', 0.0474746303197974],
#    ['2022-01-06', 0.0247534327672838],
#    ['2022-01-07', 0.0073081042912637],
#    ['2022-01-10', -0.0085313310709853]],
#   'roe': [['2022-01-05', 1.540135427],
#    ['2022-01-06', 1.540135427],
#    ['2022-01-07', 1.540135427],
#    ['2022-01-10', 1.540135427]],
#   'debt_ratio': [['2022-01-05', 72.30142696],
#    ['2022-01-06', 72.30142696],
#    ['2022-01-07', 72.30142696],
#    ['2022-01-10', 72.30142696]]},
#  'meta': {'channels': ['close', 'debt_ratio', 'ret_1d', 'roe'],
#   'source': 'master_table_denorm.csv'}}

# %%
import sys
sys.path.append("/workspace/ship-ai")

from engine.tool2_macro_pulse import get_macro_pulse_engine

resp = get_macro_pulse_engine(
)
resp
# Out:
# {'as_of_date': '2024-12-30',
#  'windows': {'short_90d': {'days': 90,
#    'indicators': {'bdi_proxy': {'level': 5.920000076293945,
#      'mom': -0.41269840068437497,
#      'mean': 7.48786886402818,
#      'std': 1.1885046887139288,
#      'zscore': -1.3191944488084544},
#     'newbuild_proxy': {'level': 124.53917521559652,
#      'mom': 0.0041999027141180496,
#      'mean': 124.33327995486728,
#      'std': 0.22392136074088323,
#      'zscore': 0.9194980775750682},
#     'wti': {'level': 70.98999786376953,
#      'mom': 0.012696139928975886,
#      'mean': 70.17491775262552,
#      'std': 2.0774987267858527,
#      'zscore': 0.39233723738788656}}},
#   'mid_365d': {'days': 365,
#    'indicators': {'bdi_proxy': {'level': 5.920000076293945,
#      'mom': -0.44256119208213235,
#      'mean': 10.99068440961056,
#      'std': 2.5322362531212823,
#      'zscore': -2.0024530993371545},
#     'newbuild_proxy': {'level': 124.53917521559652,
#      'mom': 0.024415729022523883,
# ...
